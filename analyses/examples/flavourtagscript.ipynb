# %%
import uproot
import hist
from hist import Hist
import matplotlib.pyplot as plt
import numpy as np
import mplhep as hep

# %%
uproot_thing = uproot.open("/home/submit/caitl961/FCCAnalyzer/output_h_bb_ee_40GeV_flavourtag.root")
for key in uproot_thing.keys():
    print(key)
# Out:
# wzp6_ee_nunuH_Hbb_ecm240;1
# wzp6_ee_nunuH_Hbb_ecm240/muons_all_p_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/muons_all_theta_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/muons_all_phi_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/muons_all_q_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/muons_all_no_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/electrons_all_p_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/electrons_all_theta_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/electrons_all_phi_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/electrons_all_q_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/electrons_all_no_cut0;1
# wzp6_ee_nunuH_Hbb_ecm240/cutFlow;1
# wzp6_ee_nunuH_Hbb_ecm240/electron1_p;1
# wzp6_ee_nunuH_Hbb_ecm240/electron2_p;1
# wzp6_ee_nunuH_Hbb_ecm240/ee_recoil_m_nOne;1
# wzp6_ee_nunuH_Hbb_ecm240/ee_p_nOne;1
# wzp6_ee_nunuH_Hbb_ecm240/cosThetaMiss_nOne;1
# wzp6_ee_nunuH_Hbb_ecm240/missingEnergy_nOne;1
# wzp6_ee_nunuH_Hbb_ecm240/acolinearity_nOne;1
# wzp6_ee_nunuH_Hbb_ecm240/zee_m_nOne;1
# wzp6_ee_nunuH_Hbb_ecm240/zee_m;1
# wzp6_ee_nunuH_Hbb_ecm240/muons_no;1
# ...

# %%
zcc_hbb_jet_p = uproot_thing['wzp6_ee_eeH_Hbb_ecm240/jet_p'].to_hist()
hep.histplot([zcc_hbb_jet_p])
plt.xlabel('Momentum')
# Out:
# Text(0.5, 0, 'Momentum')

# %%
zcc_hbb_jet_const = uproot_thing['wzp6_ee_eeH_Hbb_ecm240/jet_nconst'].to_hist()
hep.histplot([zcc_hbb_jet_const])
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x2b1e8f900fd0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
probabilityb0=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/recojet_isB_jet0'].to_hist()
probabilityb1=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/recojet_isB_jet1'].to_hist()
hep.histplot([probabilityb0, probabilityb1])
plt.show()

# %%
mass_higgs=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/jet0_mass'].to_hist()
hep.histplot([mass_higgs])
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x2b1e8f9e8ca0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mass_higgs=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/jet1_mass'].to_hist()
hep.histplot([mass_higgs])
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x2b1e8faeeb60>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mass_higgs=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/dijet_higgs_m_reco'].to_hist()
hep.histplot([mass_higgs])
# Out:
# /work/submit/submit-software/conda/envs/fcc-ee/lib/python3.10/site-packages/mplhep/utils.py:197: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x2b1e8fea6470>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
p_higgs=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/dijet_higgs_p_reco'].to_hist()
hep.histplot([p_higgs])
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x2b1e8fcbfd90>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
print(mass_higgs.sum())
# Out:
# WeightedSum(value=3385.57, variance=508.363)

# %%
mass_mc_h=uproot_thing['wzp6_ee_eeH_Hbb_ecm240/jet1_mass'].to_hist()
hep.histplot([mass_mc_h])
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x2ba9f18ef4c0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mass_mc_z=uproot_thing['wzp6_ee_ccH_Hbb_ecm240/meta'].to_hist()
hep.histplot([mass_mc_z])
plt.yscale('log')
# Out:
# /work/submit/submit-software/conda/envs/fcc-ee/lib/python3.10/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: divide by zero encountered in divide
#   counts = sumw / scale
# /work/submit/submit-software/conda/envs/fcc-ee/lib/python3.10/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: invalid value encountered in divide
#   counts = sumw / scale
